# %% [markdown]
# # Intro to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
plt.show()

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x, y);

# %%
# 1st method
fig = plt.figure() #creates a figure
ax = fig.add_subplot()
plt.show()

# %%
#2nd method
fig = plt.figure() 
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]);

# %% [markdown]
# ## Matplotlib example workflow

# %%
# import matplotlib
# 1) Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2) setup plot
fig, ax = plt.subplots(figsize = (10, 10))

# 3) plot the data
ax.plot(x, y)

# 4) Customize plot

ax.set(title = 'Simple Plot',
      xlabel = 'X - Axis',
      ylabel = 'Y - Axis')
# 5) save and show figure
fig.savefig('images/sample-plot.png')

plt.show();

# %% [markdown]
# ## Making figures with numpy arrays
#
# * Line plot
# * Scatter Plot
# * bar plot
# * histplot
# * subplot

# %%
# Create some data
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# create scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
#another scatter
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# plot from dictionary
nut_butter_prices = {'Almond butter': 10,
                    'Peanut butter': 8,
                    'Cashew butter': 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title = "David's nut butter store", ylabel = "Price $");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# data
x = np.random.randn(1000) #randn returns numbers in a normal distribution
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### two options for subplots

# %%
#subplot 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize = (10, 5))

#plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([  5.,  26.,  95., 192., 304., 252.,  88.,  31.,   6.,   1.]),
#  array([-3.4059021 , -2.66431272, -1.92272333, -1.18113394, -0.43954456,
#          0.30204483,  1.04363421,  1.7852236 ,  2.52681298,  3.26840237,
#          4.00999175]),
#  <BarContainer object of 10 artists>)

# %%
# subplot 2
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (10,5))
# Plot to each different index
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10))
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1].hist(np.random.randn(1000))
# Out:
# (array([  7.,  34.,  76., 141., 222., 184., 170., 100.,  49.,  17.]),
#  array([-2.76728206, -2.2320207 , -1.69675934, -1.16149798, -0.62623662,
#         -0.09097526,  0.4442861 ,  0.97954746,  1.51480882,  2.05007018,
#          2.58533154]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Plotting from pandas dataframes

# %%
car_sales = pd.read_csv('car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
ts = pd.Series(np.random.randn(1000),
              index = pd.date_range('1/1/2023', periods = 1000))
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
car_sales['Sales Date'] = pd.date_range('1/1/2020', periods = len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Sales Date
# 0  Toyota  White         150043      4   4000.0 2020-01-01
# 1   Honda    Red          87899      4   5000.0 2020-01-02
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03
# 3     BMW  Black          11179      5  22000.0 2020-01-04
# 4  Nissan  White         213095      4   3500.0 2020-01-05
# 5  Toyota  Green          99213      4   4500.0 2020-01-06
# 6   Honda   Blue          45698      4   7500.0 2020-01-07
# 7   Honda   Blue          54738      4   7000.0 2020-01-08
# 8  Toyota  White          60000      4   6250.0 2020-01-09
# 9  Nissan  White          31600      4   9700.0 2020-01-10

# %%
car_sales['Total Sales'] = car_sales['Price'].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10      76450.0

# %%
#plot the sales

car_sales.plot(x = 'Sales Date', y = 'Total Sales');

# %%
# Reassign price to int
car_sales['Price'] = car_sales["Price"].astype(int)

# Plot scatter plot with price column as numeric
car_sales.plot(x = 'Odometer (KM)', y = 'Price', kind = 'scatter');

# %%
# Bar graph
x = np.random.rand(10, 4)

df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.071338  0.823244  0.417676  0.595571
# 1  0.137899  0.236911  0.672381  0.509778
# 2  0.418639  0.795769  0.800867  0.603037
# 3  0.283298  0.778012  0.268117  0.878591
# 4  0.353158  0.647555  0.728219  0.488350
# 5  0.833872  0.471604  0.366897  0.360601
# 6  0.384571  0.527417  0.118033  0.565829
# 7  0.059300  0.108002  0.513580  0.843445
# 8  0.406251  0.263681  0.869262  0.396353
# 9  0.267355  0.739346  0.368892  0.915550

# %%
df.plot.bar();

# %%
df.plot(kind = 'bar');

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500 2020-01-05      41500.0
# 5  Toyota  Green          99213      4   4500 2020-01-06      46000.0
# 6   Honda   Blue          45698      4   7500 2020-01-07      53500.0
# 7   Honda   Blue          54738      4   7000 2020-01-08      60500.0
# 8  Toyota  White          60000      4   6250 2020-01-09      66750.0
# 9  Nissan  White          31600      4   9700 2020-01-10      76450.0

# %%
car_sales.plot(x = 'Make', y = 'Odometer (KM)', kind = 'bar');

# %%
#histograms

car_sales['Odometer (KM)'].plot.hist();

# %%
car_sales['Odometer (KM)'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales['Odometer (KM)'].plot.hist(bins = 30);

# %%
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope
# 0   63    1   3       145   233    1        0      150      0      2.3      0  \
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# create a hist of age

heart_disease['age'].plot.hist(bins = 10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope
# 0   63    1   3       145   233    1        0      150      0      2.3      0  \
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize = (10, 30), subplots = True);

# %%
heart_disease.plot.scatter(x = 'trestbps', y = 'chol');

# %% [markdown]
# ## OO Method

# %%
over_50 = heart_disease[heart_disease['age'] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope
# 0   63    1   3       145   233    1        0      150      0      2.3      0  \
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot method
over_50.plot(kind = 'scatter', x = 'age', y = 'chol', c = 'target'); #c is color

# %%
# OO method mixed with pyplot

fig, ax = plt.subplots(figsize = (10, 6))
over_50.plot(kind = 'scatter', x = 'age', y = 'chol', c = 'target', ax = ax);
ax.set_xlim([45, 100])
# Out:
# (45.0, 100.0)

# %%
# OO only (The better way with more customization)
fig, ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50['age'], y = over_50['chol'], c = over_50['target'])
#customize
ax.set(title = 'Heart Disearse and Cholesterol Levels', xlabel = 'Age', ylabel = 'Cholesterol');

#add a legend
ax.legend(*scatter.legend_elements(), title = 'Target') # * grabs the values from scatter and unpacks the legend elements

#add horizontal line
ax.axhline(over_50['chol'].mean(), linestyle = '--')

# %%
#subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows = 2, ncols = 1, figsize = (10,10), sharex = True) #sharex makes it so both graphs have one x axis at the bottom

#add to ax0
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c = over_50['target'])

#customize ax0
ax0.set(title = 'Heart Disease and Cholesterol Levels', ylabel= 'Cholesterol')
ax0.legend(*scatter.legend_elements(), title = 'Target')
# add mean line
ax0.axhline(over_50['chol'].mean(), linestyle = '--');

#add to ax1
scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c = over_50['target'])

#customize ax1
ax1.set(title = 'Heart Disease and Heart Rate', xlabel = 'Age', ylabel= 'Heart Rate')
ax1.legend(*scatter.legend_elements(), title = 'Target')
# add mean line
ax1.axhline(over_50['thalach'].mean(), linestyle = '--');


#add title to entire figure

fig.suptitle('Heart Disease Analysis', fontsize = 16, fontweight = 'bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ## Customizing Matplotlib plots

# %%
# See different available styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500 2020-01-05      41500.0

# %%
car_sales['Price'].plot();

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
car_sales['Price'].plot();

# %%
plt.style.use('Solarize_Light2')

# %%
car_sales['Price'].plot();

# %%
car_sales.plot(x = "Odometer (KM)", y = 'Price', kind = 'scatter');

# %%
#random data

x = np.random.randn(10, 4)
x
# Out:
# array([[-0.48387092, -0.26544099,  0.38911582,  2.42209376],
#        [-1.12809583, -0.60581703, -0.8520499 , -0.73907255],
#        [ 1.57086859,  1.5903682 ,  0.11029609, -0.5995945 ],
#        [ 0.07216186,  0.83452171,  0.95428068,  0.13499694],
#        [ 0.23217042,  0.14971957, -0.6577233 , -0.15483028],
#        [ 1.72556478,  0.56284343, -0.60352709, -1.41034583],
#        [-0.123864  ,  0.21690562, -0.46355638, -0.13003291],
#        [ 0.60704676, -0.72860896, -0.72992724,  0.37186378],
#        [ 0.35874235,  1.65347222, -1.19816789, -0.01071848],
#        [ 0.5505711 , -0.05912684, -1.64618987, -1.03831636]])

# %%
df = pd.DataFrame(x, columns =['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.483871 -0.265441  0.389116  2.422094
# 1 -1.128096 -0.605817 -0.852050 -0.739073
# 2  1.570869  1.590368  0.110296 -0.599594
# 3  0.072162  0.834522  0.954281  0.134997
# 4  0.232170  0.149720 -0.657723 -0.154830
# 5  1.725565  0.562843 -0.603527 -1.410346
# 6 -0.123864  0.216906 -0.463556 -0.130033
# 7  0.607047 -0.728609 -0.729927  0.371864
# 8  0.358742  1.653472 -1.198168 -0.010718
# 9  0.550571 -0.059127 -1.646190 -1.038316

# %%
ax = df.plot(kind = 'bar')

# %%
#Customize plot

ax = df.plot(kind = 'bar')
#labels and title
ax.set(title = 'Random Number Bar Graph', xlabel = 'Row Number', ylabel = 'Random Number')
#Legend
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# OO only (The better way with more customization)
fig, ax = plt.subplots(figsize = (10,6))
scatter = ax.scatter(x = over_50['age'], 
                     y = over_50['chol'], 
                     c = over_50['target'], 
                     cmap = 'winter') #This changes the color scheme
#customize
ax.set(title = 'Heart Disearse and Cholesterol Levels', xlabel = 'Age', ylabel = 'Cholesterol');

#add a legend
ax.legend(*scatter.legend_elements(), title = 'Target') # * grabs the values from scatter and unpacks the legend elements

#add horizontal line
ax.axhline(over_50['chol'].mean(), linestyle = '--')

# %%
#customizing the x and y axis limitations

#subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows = 2, ncols = 1, figsize = (10,10), sharex = True) #sharex makes it so both graphs have one x axis at the bottom

#add to ax0
scatter = ax0.scatter(x = over_50['age'], y = over_50['chol'], c = over_50['target'], cmap = 'winter')

#customize ax0
ax0.set(title = 'Heart Disease and Cholesterol Levels', ylabel= 'Cholesterol')
#change the axis limits
ax0.set_xlim([50, 80])
ax0.set_ylim([60, 600])

ax0.legend(*scatter.legend_elements(), title = 'Target')

# add mean line
ax0.axhline(over_50['chol'].mean(), linestyle = '--');

#add to ax1
scatter = ax1.scatter(x = over_50['age'], y = over_50['thalach'], c = over_50['target'], cmap = 'winter')

#customize ax1
ax1.set(title = 'Heart Disease and Heart Rate', xlabel = 'Age', ylabel= 'Heart Rate')
#change the axis limits
ax1.set_xlim([50, 80])
ax1.set_ylim([60, 200])

ax1.legend(*scatter.legend_elements(), title = 'Target')

# add mean line
ax1.axhline(over_50['thalach'].mean(), linestyle = '--');


#add title to entire figure

fig.suptitle('Heart Disease Analysis', fontsize = 16, fontweight = 'bold')
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')
